# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("test.csv")

# %%
df.drop(["which of the recreational activity do you like to perform?"],axis=1,inplace=True)

# %%
df.rename(columns={'AGE OF THE PERSON?':'AGE'},inplace=True)

# %%
df.fillna(0,inplace=True)
df=df.astype(int)

# %%
df['ID']=df.index

# %%
df=df[['ID','AGE','YOGA','SLIDES','CRICKET','JOGGING','BADMINTON','BASKETBALL','VOLLEYBALL','EVENING MEETINGS']]

# %%
df
# Out:
#     ID  AGE  YOGA  SLIDES  CRICKET  JOGGING  BADMINTON  BASKETBALL  \
# 0    0   25     1       1        1        0          1           0
# 1    1   23     0       0        1        0          0           0
# 2    2   24     1       0        1        1          0           1
# 3    3   23     0       0        0        0          0           0
# 4    4   24     1       0        0        1          0           0
# 5    5   31     1       0        1        0          0           0
# 6    6   24     0       0        0        0          0           0
# 7    7   24     0       0        0        0          1           0
# 8    8   22     0       0        1        0          0           0
# 9    9   45     0       0        1        0          0           0
# 10  10   24     0       0        1        0          0           0
# 11  11   25     0       0        1        0          0           0
# 12  12   25     0       0        0        1          0           0
# ...

# %%
pd.concat([df]*20, ignore_index=True)
# Out:
#       ID  AGE  YOGA  SLIDES  CRICKET  JOGGING  BADMINTON  BASKETBALL  \
# 0      0   25     1       1        1        0          1           0
# 1      1   23     0       0        1        0          0           0
# 2      2   24     1       0        1        1          0           1
# 3      3   23     0       0        0        0          0           0
# 4      4   24     1       0        0        1          0           0
# ...   ..  ...   ...     ...      ...      ...        ...         ...
# 1015  46   18     1       1        1        1          1           1
# 1016  47   17     1       1        1        0          0           1
# 1017  48   76     1       0        0        1          0           0
# 1018  49    8     0       1        0        0          0           0
# 1019  50   22     0       0        0        0          0           0
#
#       VOLLEYBALL  EVENING MEETINGS
# 0              1                 1
# 1              0                 0
# ...

# %%
newdf.loc[newdf['AGE']<12,['SLIDES']]=1
newdf.loc[newdf['AGE']>12,['SLIDES']]=0
newdf.loc[newdf['AGE']>70,['JOGGING']]=0
newdf.loc[newdf['AGE']>70,['CRICKET']]=0
newdf.loc[newdf['AGE']>70,['BASKETBALL']]=0

# %%
newdf
# Out:
#       ID  AGE  YOGA  SLIDES  CRICKET  JOGGING  BADMINTON  BASKETBALL  \
# 0      0   25     1       0        1        0          1           0
# 1      0   25     1       0        1        0          1           0
# 2      0   25     1       0        1        0          1           0
# 3      0   25     1       0        1        0          1           0
# 4      0   25     1       0        1        0          1           0
# ...   ..  ...   ...     ...      ...      ...        ...         ...
# 1015  50   22     0       0        0        0          0           0
# 1016  50   22     0       0        0        0          0           0
# 1017  50   22     0       0        0        0          0           0
# 1018  50   22     0       0        0        0          0           0
# 1019  50   22     0       0        0        0          0           0
#
#       VOLLEYBALL  EVENING MEETINGS
# 0              1                 1
# 1              1                 1
# ...

# %%
newdf.to_csv('test_1.csv')
